# %%
"""PREREQUISITES
(base) conda install -c anaconda numpy
(base) conda install -c anaconda pandas
(base) conda install -c conda-forge matplotlib
"""
# Out:
# 'PREREQUISITES\n(base) conda install -c anaconda numpy\n(base) conda install -c anaconda pandas\n(base) conda install -c conda-forge matplotlib\n'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from matplotlib import colors
from matplotlib.ticker import PercentFormatter

# %%
# LOAD FUEL ECONOMY DATA
data = pd.read_csv("data/vehicles.csv")
# Out:
# C:\Users\rdy2dve\AppData\Local\Temp\ipykernel_29316\748748551.py:2: DtypeWarning: Columns (70,71,72,73,74,76,79) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("data/vehicles.csv")

# %%
data.columns
# Out:
# Index(['barrels08', 'barrelsA08', 'charge120', 'charge240', 'city08',
#        'city08U', 'cityA08', 'cityA08U', 'cityCD', 'cityE', 'cityUF', 'co2',
#        'co2A', 'co2TailpipeAGpm', 'co2TailpipeGpm', 'comb08', 'comb08U',
#        'combA08', 'combA08U', 'combE', 'combinedCD', 'combinedUF', 'cylinders',
#        'displ', 'drive', 'engId', 'eng_dscr', 'feScore', 'fuelCost08',
#        'fuelCostA08', 'fuelType', 'fuelType1', 'ghgScore', 'ghgScoreA',
#        'highway08', 'highway08U', 'highwayA08', 'highwayA08U', 'highwayCD',
#        'highwayE', 'highwayUF', 'hlv', 'hpv', 'id', 'lv2', 'lv4', 'make',
#        'model', 'mpgData', 'phevBlended', 'pv2', 'pv4', 'range', 'rangeCity',
#        'rangeCityA', 'rangeHwy', 'rangeHwyA', 'trany', 'UCity', 'UCityA',
#        'UHighway', 'UHighwayA', 'VClass', 'year', 'youSaveSpend', 'guzzler',
#        'trans_dscr', 'tCharger', 'sCharger', 'atvType', 'fuelType2', 'rangeA',
#        'evMotor', 'mfrCode', 'c240Dscr', 'charge240b', 'c240bDscr',
# ...

# %%
## ANNUAL PETROLEUM CONSUMPTION IN BARRELS FOR PRIMARY FUEL TYPE: co2TailpipeGpm

# Create Dataframe
co2TailpipeGpm = data['co2TailpipeGpm']

# Calculate descriptive statistics
co2TailpipeGpm_mean = np.average(co2TailpipeGpm)
co2TailpipeGpm_med = np.median(co2TailpipeGpm)
co2TailpipeGpm_std = np.std(co2TailpipeGpm)
co2TailpipeGpm_title = "Histogram of co2TailpipeGpm; mean={}, median={}, stdev={}".format(round(co2TailpipeGpm_mean,2),round(co2TailpipeGpm_med,2),round(co2TailpipeGpm_std,2))

# Calculate bins based on Devore reasonable rule of thumb
co2TailpipeGpm_bins = int(round(math.sqrt(len(co2TailpipeGpm)),0))
co2TailpipeGpm_bins

fig, axs = plt.subplots(1, 1,
                        figsize =(7, 5),
                        tight_layout = 2)

# Add Text watermark
fig.text(0.9, 0.15, 'ADS500A',
         fontsize = 12,
         color ='red',
         ha ='right',
         va ='bottom',
         alpha = 0.5)

# the histogram of the data
n, bins, patches = axs.hist(co2TailpipeGpm, bins=co2TailpipeGpm_bins, density=True)

axs.set_title(co2TailpipeGpm_title)
axs.set_xlabel('Tailpipe CO2 in Grams/Mile')
axs.set_ylabel('Probability Density')
 
# Show plot
plt.show()

# %%
## ANNUAL PETROLEUM CONSUMPTION IN BARRELS FOR PRIMARY FUEL TYPE: barrels08

# Create Dataframe
barrels08 = data['barrels08']

# Calculate descriptive statistics
barrels08_mean = np.average(barrels08)
barrels08_med = np.median(barrels08)
barrels08_std = np.std(barrels08)
barrels08_title = "Histogram of barrels08; mean={}, median={}, stdev={}".format(round(barrels08_mean,2),round(barrels08_med,2),round(barrels08_std,2))

# Calculate bins based on Devore reasonable rule of thumb
barrels08_bins = int(round(math.sqrt(len(barrels08)),0))
barrels08_bins

fig, axs = plt.subplots(1, 1,
                        figsize =(7, 5),
                        tight_layout = 2)

# Add Text watermark
fig.text(0.9, 0.15, 'ADS500A',
         fontsize = 12,
         color ='red',
         ha ='right',
         va ='bottom',
         alpha = 0.5)

# the histogram of the data
n, bins, patches = axs.hist(barrels08, bins=barrels08_bins, density=True)

axs.set_title(barrels08_title)
axs.set_xlabel('Annual Petroleum Consumption in Barrels')
axs.set_ylabel('Probability Density')
 
# Show plot
plt.show()
